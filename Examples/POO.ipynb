# %% [markdown]
# # **Introducción a la Programación Orientada a Objetos**
#
# **Docente:** PhD Jorge Rudas
#
# **Aprendizaje de Máquina - 2025 II**
#
# **Institución Universitaria del Caribe - UniCaribe**

# %% [markdown]
# # **¿Qué es la POO?**

# %% [markdown]
# La Programación Orientada a Objetos (POO) es un paradigma donde el código se organiza en clases (plantillas) y objetos (instancias).
# Permite modelar problemas del mundo real con atributos (datos) y métodos (acciones).

# %%
class MiClase:
    """Un prototipo de una class."""

    def __init__(self, nombre):
        self.nombre = nombre

    def holamundo(self):
        return f"Hola Mundo, {self.nombre}!"

# %%
# Ejemplo de uso:
mi_primer_objeto = MiClase("Jorge")
print(mi_primer_objeto.holamundo())
# Out:
# Hola Mundo, Jorge!

# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre   # atributo
        self.edad = edad

    def saludar(self):         # método
        return f"Hola, soy {self.nombre} y tengo {self.edad} años."

# Crear objetos
p1 = Persona("Ana", 25)
p2 = Persona("Luis", 30)

print(p1.saludar())
print(p2.saludar())
# Out:
# Hola, soy Ana y tengo 25 años.
# Hola, soy Luis y tengo 30 años.

# %% [markdown]
# #**Discutamos!**
#
# 1.   Clase
# 2.   Objetos
# 3.   Constructor
# 4.   Metodos
# 5.   Atributos

# %% [markdown]
# # 1. **Encapsulación**
#
# Ocultar atributos internos para protegerlos. Se usan guiones bajos por convención (**_privado**, **__muy_privado**).

# %%
class Cuenta:
    def __init__(self, saldo):
        self.banco = "BanColombia"
        self._tipo_cuenta = "ahorro"
        self.__saldo = saldo   # atributo privado

    def depositar(self, monto):
        self.__saldo += monto

    def ver_saldo(self):
        return self.__saldo

c = Cuenta(100)
print(c.ver_saldo())
# Out:
# 100

# %%
c._tipo_cuenta
# Out:
# 'ahorro'

# %% [markdown]
# # **2. Herencia**
#
# Permite que una clase herede atributos y métodos de otra.

# %%
class Animal:
    def __init__(self, nombre):
        self.nombre = nombre

    def hablar(self):
        return "Hace un sonido"
    
    def saltar(self):
        return "Estoy saltando..."

class Perro(Animal):   # hereda de Animal
    def hablar(self):
        return "Guau"

class Gato(Animal):
    def hablar(self):
        return "Miau"

for a in [Perro("Firulais"), Gato("Michi")]:
    print(a.nombre, "→", a.hablar())
# Out:
# Firulais → Guau
# Michi → Miau

# %%
perro1 = Perro('Mateo')
perro2 = Perro('Juan')

gato1 = Gato('Cami')

print(gato1.saltar())
# Out:
# Estoy saltando...

# %% [markdown]
# # **3. Polimorfismo**
#
# El polimorfismo en POO significa que diferentes clases pueden tener un mismo método (misma interfaz), pero con comportamientos distintos.
# Esto permite tratar objetos de distintas clases de forma uniforme.

# %%
class Animal:
    def hablar(self):
        return "Hace un sonido"

class Perro(Animal):
    def hablar(self):
        return "Guau 🐶"

class Gato(Animal):
    def hablar(self):
        return "Miau 🐱"

class Pajaro(Animal):
    def hablar(self):
        return "Pío 🐦"

# Lista con diferentes animales
animales = [Perro(), Gato(), Pajaro(), Animal()]

# Polimorfismo: llamo al mismo método "hablar"
for animal in animales:
    print(animal.hablar())
# Out:
# Guau 🐶
# Miau 🐱
# Pío 🐦
# Hace un sonido

# %% [markdown]
# * El polimorfismo permite usar la misma interfaz (método con mismo nombre) en objetos diferentes.
#
# * Cada clase implementa su propia lógica.
#
# * Es muy útil para manejar colecciones de objetos heterogéneos sin tener que distinguir tipos con if/else.

# %% [markdown]
# # **4. Métodos Especiales (Dunder methods)**
#
# Python permite sobrecargar operadores con métodos mágicos (__init__, __str__, __len__, etc.).

# %%
class Libro:
    def __init__(self, titulo, autor):
        self.titulo = titulo
        self.autor = autor

    def __str__(self):
        return f"{self.titulo} de {self.autor}"


l = Libro("1984", "Orwell")
print(l)   # llama a __str__
# Out:
# 1984 de Orwell

# %%
class Grupo:
    def __init__(self, miembros):
        self.miembros = miembros

    def __len__(self):
        return len(self.miembros)

g = Grupo(["Ana", "Luis", "Marta"])
print(len(g))   # 3
# Out:
# 3

# %% [markdown]
# # **Instalar paquetes en CodeLab**

# %%
# !pip install numpy

# %% [markdown]
# # **Tallercito!**

# %% [markdown]
# ![Diagrama](https://cdn.goconqr.com/uploads/media/image/23798721/desktop_4203baa2-243f-41f1-aec6-5ff53f809a71.png)
